# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(train_images, _), (_, _) = keras.datasets.mnist.load_data()
train_images = (train_images.astype('float32') - 127.5) / 127.5  # Normalize to [-1, 1]
train_images = np.expand_dims(train_images, axis=-1)

BUFFER_SIZE = 60000
BATCH_SIZE = 256

dataset = tf.data.Dataset.from_tensor_slices(train_images).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# Generator Model
def build_generator():
    model = keras.Sequential([
        layers.Dense(7 * 7 * 256, use_bias=False, input_shape=(100,)),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.Reshape((7, 7, 256)),
        layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.LeakyReLU(),
        layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh')
    ])
    return model

generator = build_generator()

# Discriminator Model
def build_discriminator():
    model = keras.Sequential([
        layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same', input_shape=[28, 28, 1]),
        layers.LeakyReLU(),
        layers.Dropout(0.3),
        layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'),
        layers.LeakyReLU(),
        layers.Dropout(0.3),
        layers.Flatten(),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

discriminator = build_discriminator()

generator_optimizer = keras.optimizers.Adam(1e-4)
discriminator_optimizer = keras.optimizers.Adam(1e-4)

loss_fn = keras.losses.BinaryCrossentropy(from_logits=True)

def train_step(images):
    noise = tf.random.normal([BATCH_SIZE, 100])
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        generated_images = generator(noise, training=True)
        real_output = discriminator(images, training=True)
        fake_output = discriminator(generated_images, training=True)
        gen_loss = loss_fn(tf.ones_like(fake_output), fake_output)
        disc_loss = loss_fn(tf.ones_like(real_output), real_output) + loss_fn(tf.zeros_like(fake_output), fake_output)
    
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))

def train(dataset, epochs=50):
    for epoch in range(epochs):
        for image_batch in dataset:
            train_step(image_batch)
        print(f'Epoch {epoch+1} completed')

train(dataset, epochs=25)

# Generate and visualize images
def generate_and_show_images():
    noise = tf.random.normal([16, 100])
    generated_images = generator(noise, training=False)
    fig, axes = plt.subplots(4, 4, figsize=(5, 5))
    for i, ax in enumerate(axes.flat):
        ax.imshow(generated_images[i, :, :, 0] * 127.5 + 127.5, cmap='gray')
        ax.axis('off')
    plt.show()

generate_and_show_images()
# Out:
# d:\others\Python\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# d:\others\Python\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# d:\others\Python\Lib\site-packages\keras\src\backend\tensorflow\nn.py:780: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# Epoch 1 completed
# Epoch 2 completed
# Epoch 3 completed
# Epoch 4 completed
# Epoch 5 completed
# Epoch 6 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4024\1631538230.py in ?()
#      75         for image_batch in dataset:
#      76             train_step(image_batch)
#      77         print(f'Epoch {epoch+1} completed')
#      78
# ---> 79 train(dataset, epochs=25)
#      80
#      81 # Generate and visualize images
#      82 def generate_and_show_images():
#
# ~\AppData\Local\Temp\ipykernel_4024\1631538230.py in ?(dataset, epochs)
#      73 def train(dataset, epochs=50):
#      74     for epoch in range(epochs):
#      75         for image_batch in dataset:
# ---> 76             train_step(image_batch)
#      77         print(f'Epoch {epoch+1} completed')
#
# ~\AppData\Local\Temp\ipykernel_4024\1631538230.py in ?(images)
#      59
#      60     with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
#      61         generated_images = generator(noise, training=True)
#      62         real_output = discriminator(images, training=True)
# ---> 63         fake_output = discriminator(generated_images, training=True)
#      64         gen_loss = loss_fn(tf.ones_like(fake_output), fake_output)
#      65         disc_loss = loss_fn(tf.ones_like(real_output), real_output) + loss_fn(tf.zeros_like(fake_output), fake_output)
#      66
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# d:\others\Python\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     943                     "layers will not see the mask."
#     944                 )
#     945         finally:
#     946             # Destroy call context if we created it
# --> 947             self._maybe_reset_call_context()
#     948         return outputs
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# d:\others\Python\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# d:\others\Python\Lib\site-packages\keras\src\models\sequential.py in ?(self, inputs, training, mask)
#     211     def call(self, inputs, training=None, mask=None):
#     212         if self._functional:
# --> 213             return self._functional.call(inputs, training=training, mask=mask)
#     214
#     215         # Fallback: Just apply the layer sequence.
#     216         # This typically happens if `inputs` is a nested struct.
#
# d:\others\Python\Lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask)
#     178             masks = tree.flatten(mask)
#     179             for x, mask in zip(inputs, masks):
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#     185         return unpack_singleton(outputs)
#
# d:\others\Python\Lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     167                 op = operation_fn(node.operation)
#     168                 if call_fn is not None:
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#     174                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# d:\others\Python\Lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     633             and operation._call_has_training_arg
#     634             and training is not None
#     635         ):
#     636             kwargs["training"] = training
# --> 637         return operation(*args, **kwargs)
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# d:\others\Python\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     943                     "layers will not see the mask."
#     944                 )
#     945         finally:
#     946             # Destroy call context if we created it
# --> 947             self._maybe_reset_call_context()
#     948         return outputs
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# d:\others\Python\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# d:\others\Python\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# d:\others\Python\Lib\site-packages\keras\src\layers\regularization\dropout.py in ?(self, inputs, training)
#      57     def call(self, inputs, training=False):
#      58         if training and self.rate > 0:
# ---> 59             return backend.random.dropout(
#      60                 inputs,
#      61                 self.rate,
#      62                 noise_shape=self.noise_shape,
#
# d:\others\Python\Lib\site-packages\keras\src\backend\tensorflow\random.py in ?(inputs, rate, noise_shape, seed)
#      85 def dropout(inputs, rate, noise_shape=None, seed=None):
#      86     seed = _cast_seed(draw_seed(seed))
#      87     noise_shape = _get_concrete_noise_shape(inputs, noise_shape)
# ---> 88     return tf.nn.experimental.stateless_dropout(
#      89         inputs,
#      90         rate=rate,
#      91         noise_shape=noise_shape,
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(x, rate, seed, rng_alg, noise_shape, name)
#    5654   uniform_sampler = functools.partial(
#    5655       stateless_random_ops.stateless_random_uniform, seed=seed, alg=rng_alg)
#    5656   def dummy_rng_step():
#    5657     pass
# -> 5658   return _dropout(x=x, rate=rate, noise_shape=noise_shape,
#    5659                   uniform_sampler=uniform_sampler,
#    5660                   dummy_rng_step=dummy_rng_step, name=name,
#    5661                   default_name="stateless_dropout")
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(x, rate, noise_shape, uniform_sampler, dummy_rng_step, name, default_name)
#    5802
#    5803     noise_shape = _get_noise_shape(x, noise_shape)
#    5804     # Sample a uniform distribution on [0.0, 1.0) and select values larger
#    5805     # than or equal to `rate`.
# -> 5806     random_tensor = uniform_sampler(shape=noise_shape, dtype=x_dtype)
#    5807     keep_mask = random_tensor >= rate
#    5808     zero_tensor = constant_op.constant(0, dtype=x_dtype)
#    5809     ret = array_ops.where_v2(keep_mask, ret, zero_tensor)
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\stateless_random_ops.py in ?(shape, seed, minval, maxval, dtype, name, alg)
#     402         key, counter, alg = random_ops_util.get_key_counter_alg(seed, alg)
#     403         rnd = gen_stateless_random_ops_v2.stateless_random_uniform_v2(
#     404             shape, key=key, counter=counter, dtype=dtype, alg=alg
#     405         )
# --> 406         result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#     407     shape_util.maybe_set_static_shape(result, shape)
#     408     return result
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# d:\others\Python\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\math_ops.py in ?(x, y, name)
#    3936     y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    3937     if x.dtype == dtypes.string:
#    3938       return gen_math_ops.add(x, y, name=name)
#    3939     else:
# -> 3940       return gen_math_ops.add_v2(x, y, name=name)
#
# d:\others\Python\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(x, y, name)
#     507         _ctx, "AddV2", name, x, y)
#     508       return _result
#     509     except _core._NotOkStatusException as e:
#     510       _ops.raise_from_not_ok_status(e, name)
# --> 511     except _core._FallbackException:
#     512       pass
#     513     try:
#     514       return add_v2_eager_fallback(
#
# KeyboardInterrupt:
